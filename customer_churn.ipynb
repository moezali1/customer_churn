# %%
import os
os.environ["PYCARET_CUSTOM_LOGGING_LEVEL"] = "CRITICAL"

# %%
# import libraries
import pandas as pd
import numpy as np

# %%
# read csv data
data = pd.read_csv('https://raw.githubusercontent.com/srees1988/predict-churn-py/main/customer_churn_data.csv')

# %%
# check the data types
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# replace blanks with np.nan
data['TotalCharges'] = data['TotalCharges'].replace(' ', np.nan).astype('float64')

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
# check missing values
data.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# initialize setup
from pycaret.classification import *
s = setup(data, target = 'Churn', session_id = 123, ignore_features = ['customerID'], log_experiment = True, experiment_name = 'churn1')
# Out:
# <style type="text/css">
# #T_2c80c_row5_col1, #T_2c80c_row19_col1, #T_2c80c_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2c80c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c80c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c80c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_2c80c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c80c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2c80c_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c80c_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_2c80c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c80c_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_2c80c_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2c80c_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_2c80c_row4_col1" class="data row4 col1" >(7043, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c80c_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_2c80c_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c80c_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_2c80c_row6_col1" class="data row6 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c80c_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_2c80c_row7_col1" class="data row7 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2c80c_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_2c80c_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2c80c_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_2c80c_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2c80c_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_2c80c_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2c80c_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_2c80c_row11_col1" class="data row11 col1" >(4930, 33)</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2c80c_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_2c80c_row12_col1" class="data row12 col1" >(2113, 33)</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2c80c_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_2c80c_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2c80c_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_2c80c_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2c80c_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_2c80c_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2c80c_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_2c80c_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2c80c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_2c80c_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2c80c_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_2c80c_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2c80c_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_2c80c_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2c80c_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_2c80c_row20_col1" class="data row20 col1" >churn1</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2c80c_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_2c80c_row21_col1" class="data row21 col1" >1b56</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2c80c_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_2c80c_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_2c80c_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_2c80c_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_2c80c_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_2c80c_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_2c80c_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_2c80c_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_2c80c_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_2c80c_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_2c80c_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_2c80c_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_2c80c_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_2c80c_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_2c80c_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_2c80c_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2c80c_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_2c80c_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_2c80c_row30_col1" class="data row30

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_79e1c_ th {
#   text-align: left;
# }
# #T_79e1c_row0_col0, #T_79e1c_row0_col3, #T_79e1c_row0_col4, #T_79e1c_row0_col5, #T_79e1c_row1_col0, #T_79e1c_row1_col1, #T_79e1c_row1_col2, #T_79e1c_row1_col3, #T_79e1c_row1_col5, #T_79e1c_row1_col6, #T_79e1c_row1_col7, #T_79e1c_row2_col0, #T_79e1c_row2_col1, #T_79e1c_row2_col2, #T_79e1c_row2_col3, #T_79e1c_row2_col4, #T_79e1c_row2_col5, #T_79e1c_row2_col6, #T_79e1c_row2_col7, #T_79e1c_row3_col0, #T_79e1c_row3_col1, #T_79e1c_row3_col2, #T_79e1c_row3_col3, #T_79e1c_row3_col4, #T_79e1c_row3_col5, #T_79e1c_row3_col6, #T_79e1c_row3_col7, #T_79e1c_row4_col0, #T_79e1c_row4_col1, #T_79e1c_row4_col2, #T_79e1c_row4_col3, #T_79e1c_row4_col4, #T_79e1c_row4_col5, #T_79e1c_row4_col6, #T_79e1c_row4_col7, #T_79e1c_row5_col0, #T_79e1c_row5_col1, #T_79e1c_row5_col2, #T_79e1c_row5_col3, #T_79e1c_row5_col4, #T_79e1c_row5_col5, #T_79e1c_row5_col6, #T_79e1c_row5_col7, #T_79e1c_row6_col0, #T_79e1c_row6_col1, #T_79e1c_row6_col2, #T_79e1c_row6_col3, #T_79e1c_row6_col4, #T_79e1c_row6_col5, #T_79e1c_row6_col6, #T_79e1c_row6_col7, #T_79e1c_row7_col0, #T_79e1c_row7_col1, #T_79e1c_row7_col2, #T_79e1c_row7_col3, #T_79e1c_row7_col4, #T_79e1c_row7_col5, #T_79e1c_row7_col6, #T_79e1c_row7_col7, #T_79e1c_row8_col0, #T_79e1c_row8_col1, #T_79e1c_row8_col2, #T_79e1c_row8_col3, #T_79e1c_row8_col4, #T_79e1c_row8_col5, #T_79e1c_row8_col6, #T_79e1c_row8_col7, #T_79e1c_row9_col0, #T_79e1c_row9_col1, #T_79e1c_row9_col2, #T_79e1c_row9_col3, #T_79e1c_row9_col4, #T_79e1c_row9_col5, #T_79e1c_row9_col6, #T_79e1c_row9_col7, #T_79e1c_row10_col0, #T_79e1c_row10_col1, #T_79e1c_row10_col2, #T_79e1c_row10_col3, #T_79e1c_row10_col4, #T_79e1c_row10_col5, #T_79e1c_row10_col6, #T_79e1c_row10_col7, #T_79e1c_row11_col0, #T_79e1c_row11_col1, #T_79e1c_row11_col2, #T_79e1c_row11_col3, #T_79e1c_row11_col4, #T_79e1c_row11_col5, #T_79e1c_row11_col6, #T_79e1c_row11_col7, #T_79e1c_row12_col0, #T_79e1c_row12_col1, #T_79e1c_row12_col2, #T_79e1c_row12_col4, #T_79e1c_row12_col6, #T_79e1c_row12_col7, #T_79e1c_row13_col0, #T_79e1c_row13_col1, #T_79e1c_row13_col2, #T_79e1c_row13_col3, #T_79e1c_row13_col4, #T_79e1c_row13_col5, #T_79e1c_row13_col6, #T_79e1c_row13_col7, #T_79e1c_row14_col0, #T_79e1c_row14_col1, #T_79e1c_row14_col2, #T_79e1c_row14_col3, #T_79e1c_row14_col4, #T_79e1c_row14_col5, #T_79e1c_row14_col6, #T_79e1c_row14_col7, #T_79e1c_row15_col0, #T_79e1c_row15_col1, #T_79e1c_row15_col2, #T_79e1c_row15_col3, #T_79e1c_row15_col4, #T_79e1c_row15_col5, #T_79e1c_row15_col6, #T_79e1c_row15_col7 {
#   text-align: left;
# }
# #T_79e1c_row0_col1, #T_79e1c_row0_col2, #T_79e1c_row0_col6, #T_79e1c_row0_col7, #T_79e1c_row1_col4, #T_79e1c_row12_col3, #T_79e1c_row12_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_79e1c_row0_col8, #T_79e1c_row1_col8, #T_79e1c_row2_col8, #T_79e1c_row3_col8, #T_79e1c_row4_col8, #T_79e1c_row5_col8, #T_79e1c_row6_col8, #T_79e1c_row7_col8, #T_79e1c_row8_col8, #T_79e1c_row9_col8, #T_79e1c_row10_col8, #T_79e1c_row11_col8, #T_79e1c_row13_col8, #T_79e1c_row14_col8, #T_79e1c_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_79e1c_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_79e1c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79e1c_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_79e1c_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_79e1c_row0_col1" class="data row0 col1" >0.8067</td>
#       <td id="T_79e1c_row0_col2" class="data row0 col2" >0.8479</td>
#       <td id="T_79e1c_row0_col3" class="data row0 col3" >0.5254</td>
#       <td id="T_79e1c_row0_col4" class="data row0 col4" >0.6617</td>
#       <td id="T_79e1c_row0_col5" class="data row0 col5" >0.5849</td>
#       <td id="T_79e1c_row0_col6" class="data row0 col6" >0.4612</td>
#       <td id="T_79e1c_row0_col7" class="data row0 col7" >0.4669</td>
#       <td id="T_79e1c_row0_col8" class="data row0 col8" >0.0650</td>
#     </tr>
#     <tr>
#       <th id="T_79e1c_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_79e1c_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_79e1c_row1_col1" class="data row1 col1" >0.8063</td>
#       <td id="T_79e1c_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_79e1c_row1_col3" class="data row1 col3" >0.5097</td>
#       <td id="T_79e1c_row1_col4" class="data row1 col4" >0.6657</td>
#       <td id="T_79e1c_row1_col5" class="data row1 col5" >0.5767</td>
#       <td id="T_79e1c_row1_col6" class="data row1 col6" >0.4541</td>
#       <td id="T_79e1c_row1_col7" class="data row1 col7" >0.4613</td>
#       <td id="T_79e1c_row1_col8" class="data row1 col8" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_79e1c_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_79e1c_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_79e1c_row2_col1" class="data row2 col1" >0.8045</td>
#       <td id="T_79e1c_row2_col2" class="data row2 col2" >0.8446</td>
#       <td id="T_79e1c_row2_col3" class="data row2 col3" >0.5332</td>
#       <td id="T_79e1c_row2_col4" class="data row2 col4" >0.6499</td>
#       <td id="T_79e1c_row2_col5" class="data row2 col5" >0.5853</td>
#       <td id="T_79e1c_row2_col6" class="data row2 col6" >0.4591</td>
#       <td id="T_79e1c_row2_col7" class="data row2 col7" >0.4633</td>
#       <td id="T_79e1c_row2_col8" class="data row2 col8" >0.8230</td>
#     </tr>
#     <tr>
#       <th id="T_79e1c_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_79e1c_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_79e1c_row3_col1" class="data row3 col1" >0.8041</td>
#       <td id="T_79e1c_row3_col2" class="data row3 col2" >0.8472</td>
#       <td id="T_79e1c_row3_col3" class="data row3 col3" >0.5105</td>
#       <td id="T_79e1c_row3_col4" class="data row3 col4" >0.6590</td>
#       <td id="T_79e1c_row3_col5" class="data row3 col5" >0.5744</td>
#       <td id="T_79e1c_row3_col6" class="data row3 col6" >0.4499</td>
#       <td id="T_79e1c_row3_col7" class="data row3 col7" >0.4567</td>
#       <td id="T_79e1c_row3_col8" class="data row3 col8" >0.1750</td>
#     </tr>
#     <tr>
#       <th id="T_79e1c_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_79e1c_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_79e1c_row4_col1" class="data row4 col1" >0.8008</td>
#       <td id="T_79e1c_row4_col2" class="data row4 col2" >0.8375</td>
#       <td id="T_79e1c_row4_col3" class="data row4 col3" >0.5480</td>
#       <td id="T_79e1c_row4_col4" class="data row4 col4" >0.6349</td>
#       <td id="T_79e1c_row4_col5" class="data row4 col5" >0.5876</td>
#       <td id="T_79e1c_row4_col6" class="data row4 col6" >0.4574</td>
#       <td id="T_79e1c_row4_col7" class="data row4 col7" >0.4599</td>
#       <td id="T_79e1c_row4_col8" class="data row4 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_79e1c_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_79e1c_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_79e1c_row5_col1" class="data row5 col1" >0.8004</td>
#       <td id="T_79e1c_row5_col2" class="data row5 col2" >0.8372</td>
#       <td id="T_79e1c_row5_col3" class="data row5 col3" >0.5238</td>
#       <td id="T_79e1c_row5_col4" class="data row5 col4" >0.6426</td>
#       <td id="T_79e1c_row5_col5" class="data row5 col5"

# %%
print(best_model)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=123)

# %%
# save pipeline
save_model(best_model, 'my_first_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True,
#                                        features_todrop=['customerID'],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Churn',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  nu...
#                  ('dummy', Dummify(target='Churn')),
#                  ('fix_perfect', Remove_100(target='Churn')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#                                      learning_rate=1.0, n_estimators=50,
#                                      random_state=123)]],
#           verbose=False),
#  'my_first_pipeline.pkl')

# %%
from sklearn import set_config
set_config(display = 'diagram')

# %%
load_model('my_first_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=None,
#          steps=[('dtypes',
#                  DataTypes_Auto_infer(categorical_features=[],
#                                       display_types=True,
#                                       features_todrop=['customerID'],
#                                       id_columns=[],
#                                       ml_usecase='classification',
#                                       numerical_features=[], target='Churn',
#                                       time_features=[])),
#                 ('imputer',
#                  Simple_Imputer(categorical_strategy='not_available',
#                                 fill_value_categorical=None,
#                                 fill_value_numerical=None,
#                                 nu...
#                 ('dummy', Dummify(target='Churn')),
#                 ('fix_perfect', Remove_100(target='Churn')),
#                 ('clean_names', Clean_Colum_Names()),
#                 ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                 ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                 ['trained_model',
#                  AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#                                     learning_rate=1.0, n_estimators=50,
#                                     random_state=123)]],
#          verbose=False)

# %%
# !mlflow ui
# Out:
# ^C
